# %% [markdown]
# # Predicting House Sale Prices

# %% [markdown]
# In this project we focus on implementing a linear regression model in order to predict house prices on a data set from the city of Ames, Iowa. This data is from the years 2006-2010.

# %% [markdown]
# The first thing we want to do is lay out the functions we will be using.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from scipy import stats
from sklearn.model_selection import KFold

# %%
df = pd.read_csv("AmesHousing.tsv", delimiter= "\t")
pd.options.display.max_columns = 999

# %%
def transform_features(df):
    return df

def select_features(df):
    return df[['Gr Liv Area', 'SalePrice']]

def train_and_test(df):
    train = df[:1460]
    test = df[1460:]
    
    numerical_train = train.select_dtypes(include=['integer','float'])
    numeric_test = test.select_dtypes(include=['integer','float'])
    
    
    features = numerical_train.columns.drop(['SalePrice'])
    
    lr = LinearRegression()
    lr.fit(train[features], train['SalePrice'])
    
    prediction = lr.predict(test[features])
    
    rmse = mean_squared_error(test['SalePrice'],prediction)**0.5
    return rmse


transform_df = transform_features(df)
filtered_df = select_features(transform_df)
rmse = train_and_test(filtered_df)

rmse
# Out:
# 57088.25161263909

# %% [markdown]
# These are the base functions of the model. We modify these to inlude selecting parts of the data set to use, cleaning the data set, and adding new features.

# %% [markdown]
# # Feature Engineering

# %%
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# 5         6  527105030           60        RL          78.0      9978   Pave
# 6         7  527127150          120        RL          41.0      4920   Pave
# 7         8  527145080          120        RL          43.0      5005   Pave
# 8         9  527146030          120        RL          39.0      5389   Pave
# 9        10  527162130           60        RL          60.0      7500   Pave
# 10       11  527163010           60        RL          75.0     10000   Pave
# 11       12  527165230           20        RL           NaN      7980   Pave
# 12       13  527166040           60        RL          63.0      8402   Pave
# 13       14  527180040           20        RL          85.0     10176   Pave
# 14       15  527182190          120        RL           NaN      6820   Pave
# 15       16  527216070           60        RL          47.0     53504   Pave
# 16       17  527225035           50        RL         152.0     12134   Pave
# 17       18  527258010           20        RL          88.0     11394   Pave
# 18       19  527276150           20        RL         140.0     19138   Pave
# 19       20  527302110           20        RL          85.0     13175   Pave
# 20       21  527358140           20        RL         105.0     11751   Pave
# 21       22  527358200           85        RL          85.0     10625   Pave
# 22       23  527368020           60        FV           NaN      7500   Pave
# 23       24  527402200           20        RL           NaN     11241   Pave
# 24       25  527402250           20        RL           NaN     12537   Pave
# 25       26  527403020           20        RL          65.0      8450   Pave
# 26       27  527404120           20        RL          70.0      8400   Pave
# 27       28  527425090           20        RL          70.0     10500   Pave
# 28       29  527427230          120        RH          26.0      5858   Pave
# 29       30  527451180          160        RM          21.0      1680   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2900   2901  916477010           20        RL          95.0     13618   Pave
# 2901   2902  921205030           20        RL          88.0     11443   Pave
# 2902   2903  921205050           20        RL          88.0     11577   Pave
# 2903   2904  923125030           20   A (agr)         125.0     31250   Pave
# 2904   2905  923202025           90        RM          78.0      7020   Pave
# 2905   2906  923203090          120        RM          32.0      4500   Pave
# 2906   2907  923203100          120        RM          32.0      4500   Pave
# 2907   2908  923205120           20        RL          90.0     17217   Pave
# 2908   2909  923225190          160        RM          41.0      2665   Pave
# 2909   2910  923225240          160        RM          41.0      2665   Pave
# 2910   2911  923225260          160        RM          42.0      3964   Pave
# 2911   2912  923225510           20        RL          58.0     10172   Pave
# 2912   2913  923226150           90        RL           NaN     11836   Pave
# 2913   2914  923226180          180        RM          21.0      1470   Pave
# 2914   2915  923226290          160        RM          21.0      1484   Pave
# 2915   2916  923227100           20        RL          80.0     13384   Pave
# 2916   2917  923228130          180        RM          21.0      1533   Pave
# 2917   2918  923228180          160        RM          21.0      1533   Pave
# 2918   2919  923228210          160        RM          21.0      1526   Pave
# 2919   2920  923228260          160        RM          21.0      1936   Pave
# 2920   2921  923228310          160        RM          21.0      1894   Pave
# 2921   2922  923229110           90        RL          55.0     12640   Pave
# 2922   2923  923230040           90        RL          63.0      9297   Pave
# 2923   2924  923250060           20        RL          80.0     17400   Pave
# 2924   2925  923251180           20        RL         160.0     20000   Pave
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0      NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2      NaN       IR1          Lvl    AllPub     Corner        Gtl
# 3      NaN       Reg          Lvl    AllPub     Corner        Gtl
# 4      NaN       IR1          Lvl    AllPub     Inside        Gtl
# 5      NaN       IR1          Lvl    AllPub     Inside        Gtl
# 6      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 7      NaN       IR1          HLS    AllPub     Inside        Gtl
# 8      NaN       IR1          Lvl    AllPub     Inside        Gtl
# 9      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 10     NaN       IR1          Lvl    AllPub     Corner        Gtl
# 11     NaN       IR1          Lvl    AllPub     Inside        Gtl
# 12     NaN       IR1          Lvl    AllPub     Inside        Gtl
# 13     NaN       Reg          Lvl    AllPub     Inside        Gtl
# 14     NaN       IR1          Lvl    AllPub     Corner        Gtl
# 15     NaN       IR2          HLS    AllPub    CulDSac        Mod
# 16     NaN       IR1          Bnk    AllPub     Inside        Mod
# 17     NaN       Reg          Lvl    AllPub     Corner        Gtl
# 18     NaN       Reg          Lvl    AllPub     Corner        Gtl
# 19     NaN       Reg          Lvl    AllPub     Inside        Gtl
# 20     NaN       IR1          Lvl    AllPub     Inside        Gtl
# 21     NaN       Reg          Lvl    AllPub     Inside        Gtl
# 22     NaN       Reg          Lvl    AllPub     Inside        Gtl
# 23     NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 24     NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 25     NaN       Reg          Lvl    AllPub     Inside        Gtl
# 26     NaN       Reg          Lvl    AllPub     Corner        Gtl
# 27     NaN       Reg          Lvl    AllPub        FR2        Gtl
# 28     NaN       IR1          Lvl    AllPub        FR2        Gtl
# 29     NaN       Reg          Lvl    AllPub     Inside        Gtl
# ...    ...       ...          ...       ...        ...        ...
# 2900   NaN       Reg          Lvl    AllPub     Corner        Gtl
# 2901   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2902   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2903   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2904   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2905   NaN       Reg          Lvl    AllPub        FR2        Gtl
# 2906   NaN       Reg          Lvl    AllPub        FR2        Gtl
# 2907   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2908   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2909   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2910   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2911   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 2912   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 2913   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2914   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2915   NaN       Reg          Lvl    AllPub     Inside        Mod
# 2916   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2917   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2918   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2919   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2920   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2921   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 2922   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2923   NaN       Reg          Low    AllPub     Inside        Mod
# 2924   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2925   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 2926   NaN       IR1          Low    AllPub     Inside        Mod
# 2927   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2928   NaN       Reg          Lvl    AllPub     Inside        Mod
# 2929   NaN       Reg          Lvl    AllPub     Inside        Mod
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 0           NAmes        Norm        Norm      1Fam      1Story             6
# 1           NAmes       Feedr        Norm      1Fam      1Story             5
# 2           NAmes        Norm        Norm      1Fam      1Story             6
# 3           NAmes        Norm        Norm      1Fam      1Story             7
# 4         Gilbert        Norm        Norm      1Fam      2Story             5
# 5         Gilbert        Norm        Norm      1Fam      2Story             6
# 6         StoneBr        Norm        Norm    TwnhsE      1Story             8
# 7         StoneBr        Norm        Norm    TwnhsE      1Story             8
# 8         StoneBr        Norm        Norm    TwnhsE      1Story             8
# 9         Gilbert        Norm        Norm      1Fam      2Story             7
# 10        Gilbert        Norm        Norm      1Fam      2Story             6
# 11        Gilbert        Norm        Norm      1Fam      1Story             6
# 12        Gilbert        Norm        Norm      1Fam      2Story             6
# 13        Gilbert        Norm        Norm      1Fam      1Story             7
# 14        StoneBr        Norm        Norm    TwnhsE      1Story             8
# 15        StoneBr        Norm        Norm      1Fam      2Story             8
# 16        Gilbert        Norm        Norm      1Fam      1.5Fin             8
# 17        StoneBr        Norm        Norm      1Fam      1Story             9
# 18        Gilbert        Norm        Norm      1Fam      1Story             4
# 19         NWAmes        Norm        Norm      1Fam      1Story             6
# 20         NWAmes        Norm        Norm      1Fam      1Story             6
# 21         NWAmes        Norm        Norm      1Fam      SFoyer             7
# 22        Somerst        Norm        Norm      1Fam      2Story             7
# 23          NAmes        Norm        Norm      1Fam      1Story             6
# 24          NAmes        Norm        Norm      1Fam      1Story             5
# 25          NAmes        Norm        Norm      1Fam      1Story             5
# 26          NAmes        Norm        Norm      1Fam      1Story             4
# 27          NAmes        Norm        Norm      1Fam      1Story             4
# 28          NAmes        Norm        Norm    TwnhsE      1Story             7
# 29         BrDale        Norm        Norm     Twnhs      2Story             6
# ...           ...         ...         ...       ...         ...           ...
# 2900       Timber        Norm        Norm      1Fam      1Story             8
# 2901       Timber        Norm        Norm      1Fam      1Story             8
# 2902       Timber        Norm        Norm      1Fam      1Story             9
# 2903      Mitchel      Artery        Norm      1Fam      1Story             1
# 2904      Mitchel        Norm        Norm    Duplex      SFoyer             7
# 2905      Mitchel        Norm        Norm     Twnhs      1Story             6
# 2906      Mitchel        Norm        Norm    TwnhsE      1Story             6
# 2907      Mitchel        Norm        Norm      1Fam      1Story             5
# 2908      MeadowV        Norm        Norm    TwnhsE      2Story             5
# 2909      MeadowV        Norm        Norm    TwnhsE      2Story             5
# 2910      MeadowV        Norm        Norm    TwnhsE      2Story             6
# 2911      Mitchel        Norm        Norm      1Fam      1Story             5
# 2912      Mitchel        Norm        Norm    Duplex      1Story             5
# 2913      MeadowV        Norm        Norm     Twnhs      SFoyer             4
# 2914      MeadowV        Norm        Norm    TwnhsE      2Story             4
# 2915      Mitchel        Norm        Norm      1Fam      1Story             5
# 2916      MeadowV        Norm        Norm     Twnhs      SFoyer             5
# 2917      MeadowV        Norm        Norm     Twnhs      2Story             4
# 2918      MeadowV        Norm        Norm     Twnhs      2Story             4
# 2919      MeadowV        Norm        Norm     Twnhs      2Story             4
# 2920      MeadowV        Norm        Norm    TwnhsE      2Story             4
# 2921      Mitchel        Norm        Norm    Duplex      1Story             6
# 2922      Mitchel        Norm        Norm    Duplex      1Story             5
# 2923      Mitchel        Norm        Norm      1Fam      1Story             5
# 2924      Mitchel        Norm        Norm      1Fam      1Story             5
# 2925      Mitchel        Norm        Norm      1Fam        SLvl             6
# 2926      Mitchel        Norm        Norm      1Fam      1Story             5
# 2927      Mitchel        Norm        Norm      1Fam      SFoyer             5
# 2928      Mitchel        Norm        Norm      1Fam      1Story             5
# 2929      Mitchel        Norm        Norm      1Fam      2Story             7
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 0                5        1960            1960        Hip   CompShg
# 1                6        1961            1961      Gable   CompShg
# 2                6        1958            1958        Hip   CompShg
# 3                5        1968            1968        Hip   CompShg
# 4                5        1997            1998      Gable   CompShg
# 5                6        1998            1998      Gable   CompShg
# 6                5        2001            2001      Gable   CompShg
# 7                5        1992            1992      Gable   CompShg
# 8                5        1995            1996      Gable   CompShg
# 9                5        1999            1999      Gable   CompShg
# 10               5        1993            1994      Gable   CompShg
# 11               7        1992            2007      Gable   CompShg
# 12               5        1998            1998      Gable   CompShg
# 13               5        1990            1990      Gable   CompShg
# 14               5        1985            1985      Gable   CompShg
# 15               5        2003            2003        Hip   CompShg
# 16               7        1988            2005      Gable   CompShg
# 17               2        2010            2010        Hip   CompShg
# 18               5        1951            1951      Gable   CompShg
# 19               6        1978            1988      Gable   CompShg
# 20               6        1977            1977        Hip   CompShg
# 21               6        1974            1974      Gable   CompShg
# 22               5        2000            2000      Gable   CompShg
# 23               7        1970            1970      Gable   CompShg
# 24               6        1971            2008      Gable   CompShg
# 25               6        1968            1968      Gable   CompShg
# 26               5        1970            1970      Gable   CompShg
# 27               5        1971            1971      Gable   CompShg
# 28               5        1999            1999      Gable   CompShg
# 29               5        1971            1971      Gable   CompShg
# ...            ...         ...             ...        ...       ...
# 2900             5        2005            2006      Gable   CompShg
# 2901             5        2005            2006        Hip   CompShg
# 2902             5        2005            2006        Hip   CompShg
# 2903             3        1951            1951      Gable   CompShg
# 2904             5        1997            1997      Gable   CompShg
# 2905             5        1998            1998        Hip   CompShg
# 2906             5        1998            1998        Hip   CompShg
# 2907             5        2006            2006      Gable   CompShg
# 2908             6        1977            1977      Gable   CompShg
# 2909             6        1977            1977      Gable   CompShg
# 2910             4        1973            1973      Gable   CompShg
# 2911             7        1968            2003      Gable   CompShg
# 2912             5        1970            1970      Gable   CompShg
# 2913             6        1970            1970      Gable   CompShg
# 2914             4        1972            1972      Gable   CompShg
# 2915             5        1969            1979      Gable   CompShg
# 2916             7        1970            1970      Gable   CompShg
# 2917             5        1970            1970      Gable   CompShg
# 2918             5        1970            1970      Gable   CompShg
# 2919             7        1970            1970      Gable   CompShg
# 2920             5        1970            1970      Gable   CompShg
# 2921             5        1976            1976      Gable   CompShg
# 2922             5        1976            1976      Gable   CompShg
# 2923             5        1977            1977      Gable   CompShg
# 2924             7        1960            1996      Gable   CompShg
# 2925             6        1984            1984      Gable   CompShg
# 2926             5        1983            1983      Gable   CompShg
# 2927             5        1992            1992      Gable   CompShg
# 2928             5        1974            1975      Gable   CompShg
# 2929             5        1993            1994      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 0         BrkFace      Plywood        Stone         112.0         TA
# 1         VinylSd      VinylSd         None           0.0         TA
# 2         Wd Sdng      Wd Sdng      BrkFace         108.0         TA
# 3         BrkFace      BrkFace         None           0.0         Gd
# 4         VinylSd      VinylSd         None           0.0         TA
# 5         VinylSd      VinylSd      BrkFace          20.0         TA
# 6         CemntBd      CmentBd         None           0.0         Gd
# 7         HdBoard      HdBoard         None           0.0         Gd
# 8         CemntBd      CmentBd         None           0.0         Gd
# 9         VinylSd      VinylSd         None           0.0         TA
# 10        HdBoard      HdBoard         None           0.0         TA
# 11        HdBoard      HdBoard         None           0.0         TA
# 12        VinylSd      VinylSd         None           0.0         TA
# 13        HdBoard      HdBoard         None           0.0         TA
# 14        HdBoard      HdBoard         None           0.0         Gd
# 15        CemntBd      Wd Shng      BrkFace         603.0         Ex
# 16        Wd Sdng      Wd Sdng         None           0.0         Gd
# 17        VinylSd      VinylSd        Stone         350.0         Gd
# 18        VinylSd      VinylSd         None           0.0         TA
# 19        Plywood      Plywood        Stone         119.0         TA
# 20        Plywood      Plywood      BrkFace         480.0         TA
# 21        Plywood      Plywood      BrkFace          81.0         TA
# 22        VinylSd      VinylSd         None           0.0         Gd
# 23        Wd Sdng      Wd Sdng      BrkFace         180.0         TA
# 24        VinylSd      VinylSd         None           0.0         TA
# 25        VinylSd      VinylSd         None           0.0         TA
# 26        Plywood      Plywood         None           0.0         TA
# 27        HdBoard      HdBoard         None           0.0         TA
# 28        MetalSd      MetalSd         None           0.0         Gd
# 29        HdBoard      HdBoard      BrkFace         504.0         TA
# ...           ...          ...          ...           ...        ...
# 2900      VinylSd      VinylSd        Stone         198.0         Gd
# 2901      VinylSd      VinylSd      BrkFace         208.0         Gd
# 2902      VinylSd      VinylSd      BrkFace         382.0         Ex
# 2903       CBlock      VinylSd         None           0.0         TA
# 2904      MetalSd      MetalSd      BrkFace         200.0         TA
# 2905      VinylSd      VinylSd      BrkFace         116.0         TA
# 2906      VinylSd      VinylSd      BrkFace         443.0         TA
# 2907      VinylSd      VinylSd         None           0.0         TA
# 2908      CemntBd      CmentBd         None           0.0         TA
# 2909      CemntBd      CmentBd         None           0.0         TA
# 2910      CemntBd      CmentBd         None           0.0         TA
# 2911      Plywood      Plywood         None           0.0         TA
# 2912      Plywood      Plywood         None           0.0         TA
# 2913      CemntBd      CmentBd         None           0.0         TA
# 2914      CemntBd      CmentBd         None           0.0         TA
# 2915      Plywood      Plywood      BrkFace         194.0         TA
# 2916      CemntBd      CmentBd         None           0.0         TA
# 2917      CemntBd      CmentBd         None           0.0         TA
# 2918      CemntBd      CmentBd         None           0.0         TA
# 2919      CemntBd      CmentBd         None           0.0         TA
# 2920      CemntBd      CmentBd         None           0.0         TA
# 2921      Plywood      Plywood         None           0.0         TA
# 2922      Plywood      Plywood         None           0.0         TA
# 2923      BrkFace      BrkFace         None           0.0         TA
# 2924      VinylSd      VinylSd         None           0.0         TA
# 2925      HdBoard      HdBoard         None           0.0         TA
# 2926      HdBoard      HdBoard         None           0.0         TA
# 2927      HdBoard      Wd Shng         None           0.0         TA
# 2928      HdBoard      HdBoard         None           0.0         TA
# 2929      HdBoard      HdBoard      BrkFace          94.0         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 0            TA     CBlock        TA        Gd            Gd            BLQ
# 1            TA     CBlock        TA        TA            No            Rec
# 2            TA     CBlock        TA        TA            No            ALQ
# 3            TA     CBlock        TA        TA            No            ALQ
# 4            TA      PConc        Gd        TA            No            GLQ
# 5            TA      PConc        TA        TA            No            GLQ
# 6            TA      PConc        Gd        TA            Mn            GLQ
# 7            TA      PConc        Gd        TA            No            ALQ
# 8            TA      PConc        Gd        TA            No            GLQ
# 9            TA      PConc        TA        TA            No            Unf
# 10           TA      PConc        Gd        TA            No            Unf
# 11           Gd      PConc        Gd        TA            No            ALQ
# 12           TA      PConc        Gd        TA            No            Unf
# 13           TA      PConc        Gd        TA            Gd            GLQ
# 14           TA      PConc        Gd        TA            Av            GLQ
# 15           TA      PConc        Gd        TA            Gd            ALQ
# 16           TA       Wood        Gd        TA            Av            GLQ
# 17           TA      PConc        Ex        TA            Av            GLQ
# 18           TA     CBlock        TA        TA            No            LwQ
# 19           TA     CBlock        Gd        TA            No            ALQ
# 20           TA     CBlock        Gd        TA            No            BLQ
# 21           TA     CBlock        Gd        TA            Gd            GLQ
# 22           TA      PConc        Gd        TA            No            GLQ
# 23           TA     CBlock        TA        TA            No            ALQ
# 24           TA     CBlock        TA        TA            No            GLQ
# 25           TA     CBlock        TA        TA            No            BLQ
# 26           TA     CBlock        TA        TA            No            ALQ
# 27           TA     CBlock        TA        TA            No            ALQ
# 28           TA      PConc        Gd        TA            No            GLQ
# 29           TA     CBlock        TA        TA            No            Rec
# ...         ...        ...       ...       ...           ...            ...
# 2900         TA      PConc        Ex        Gd            Av            GLQ
# 2901         TA      PConc        Ex        TA            Gd            GLQ
# 2902         TA      PConc        Gd        TA            Gd            GLQ
# 2903         Fa     CBlock       NaN       NaN           NaN            NaN
# 2904         Gd      PConc        Gd        TA            Gd            GLQ
# 2905         TA      PConc        Ex        TA            No            GLQ
# 2906         Gd      PConc        Ex        Gd            No            GLQ
# 2907         TA      PConc        Gd        TA            No            Unf
# 2908         TA      PConc        Gd        TA            Mn            Unf
# 2909         TA      PConc        TA        TA            No            ALQ
# 2910         TA     CBlock        Gd        TA            No            ALQ
# 2911         TA     CBlock        TA        TA            No            ALQ
# 2912         TA     CBlock        TA        TA            No            BLQ
# 2913         TA     CBlock        Gd        TA            Av            GLQ
# 2914         TA     CBlock        TA        TA            No            Rec
# 2915         TA      PConc        TA        TA            Av            Rec
# 2916         TA     CBlock        Gd        TA            Av            GLQ
# 2917         TA     CBlock        TA        TA            No            Rec
# 2918         TA     CBlock        TA        TA            No            Unf
# 2919         TA     CBlock        TA        TA            No            Unf
# 2920         TA     CBlock        TA        TA            No            Rec
# 2921         TA     CBlock        TA        TA            Gd            Rec
# 2922         TA     CBlock        TA        TA            No            ALQ
# 2923         TA     CBlock        TA        TA            No            ALQ
# 2924         TA     CBlock        TA        TA            No            ALQ
# 2925         TA     CBlock        TA        TA            Av            GLQ
# 2926         TA     CBlock        Gd        TA            Av            BLQ
# 2927         TA      PConc        Gd        TA            Av            GLQ
# 2928         TA     CBlock        Gd        TA            Av            ALQ
# 2929         TA      PConc        Gd        TA            Av            LwQ
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 
0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 0       GasA         Fa           Y      SBrkr        1656           0
# 1       GasA         TA           Y      SBrkr         896           0
# 2       GasA         TA           Y      SBrkr        1329           0
# 3       GasA         Ex           Y      SBrkr        2110           0
# 4       GasA         Gd           Y      SBrkr         928         701
# 5       GasA         Ex           Y      SBrkr         926         678
# 6       GasA         Ex           Y      SBrkr        1338           0
# 7       GasA         Ex           Y      SBrkr        1280           0
# 8       GasA         Ex           Y      SBrkr        1616           0
# 9       GasA         Gd           Y      SBrkr        1028         776
# 10      GasA         Gd           Y      SBrkr         763         892
# 11      GasA         Ex           Y      SBrkr        1187           0
# 12      GasA         Gd           Y      SBrkr         789         676
# 13      GasA         Gd           Y      SBrkr        1341           0
# 14      GasA         TA           Y      SBrkr        1502           0
# 15      GasA         Ex           Y      SBrkr        1690        1589
# 16      GasA         Gd           Y      SBrkr        1080         672
# 17      GasA         Ex           Y      SBrkr        1856           0
# 18      GasA         Ex           Y      SBrkr         864           0
# 19      GasA         TA           Y      SBrkr        2073           0
# 20      GasA         Ex           Y      SBrkr        1844           0
# 21      GasA         TA           Y      SBrkr        1173           0
# 22      GasA         Ex           Y      SBrkr         814         860
# 23      GasA         Ex           Y      SBrkr        1004           0
# 24      GasA         Ex           Y      SBrkr        1078           0
# 25      GasA         Ex           Y      SBrkr        1056           0
# 26      GasA         TA           Y      SBrkr         882           0
# 27      GasA         TA           Y      SBrkr         864           0
# 28      GasA         Ex           Y      SBrkr        1337           0
# 29      GasA         TA           Y      SBrkr         483         504
# ...      ...        ...         ...        ...         ...         ...
# 2900    GasA         Ex           Y      SBrkr        1960           0
# 2901    GasA         Ex           Y      SBrkr        2028           0
# 2902    GasA         Ex           Y      SBrkr        1838           0
# 2903    GasA         TA           Y      FuseA        1600           0
# 2904    GasA         Gd           Y      SBrkr        1368           0
# 2905    GasA         Ex           Y      SBrkr        1216           0
# 2906    GasA         Ex           Y      SBrkr        1337           0
# 2907    GasA         Ex           Y      SBrkr        1140           0
# 2908    GasA         TA           Y      SBrkr         616         688
# 2909    GasA         Ex           Y      SBrkr         925         550
# 2910    GasA         Gd           Y      SBrkr        1291        1230
# 2911    GasA         Ex           Y      SBrkr         874           0
# 2912    GasA         TA           Y      SBrkr        1652           0
# 2913    GasA         TA           Y      SBrkr         630           0
# 2914    GasA         TA           Y      SBrkr         546         546
# 2915    GasA         Fa           Y      SBrkr        1360           0
# 2916    GasA         Ex           Y      SBrkr         630           0
# 2917    GasA         TA           Y      SBrkr         546         546
# 2918    GasA         TA           Y      SBrkr         546         546
# 2919    GasA         Gd           Y      SBrkr         546         546
# 2920    GasA         TA           Y      SBrkr         546         546
# 2921    GasA         TA           Y      SBrkr        1728           0
# 2922    GasA         TA           Y      SBrkr        1728           0
# 2923    GasA         Fa           Y      SBrkr        1126           0
# 2924    GasA         Ex           Y      SBrkr        1224           0
# 2925    GasA         TA           Y      SBrkr        1003           0
# 2926    GasA         TA           Y      SBrkr         902           0
# 2927    GasA         TA           Y      SBrkr         970           0
# 2928    GasA         Gd           Y      SBrkr        1389           0
# 2929    GasA         Ex           Y      SBrkr         996        1004
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 0
# 2901          0              2              1           Gd              7
# 2902          0              3              1           Ex              9
# 2903          1              3              1           TA              6
# 2904          0              2              2           TA              8
# 2905          0              2              1           TA              5
# 2906          0              2              1           TA              5
# 2907          0              3              1           TA              6
# 2908          1              3              1           TA              5
# 2909          0              4              1           TA              6
# 2910          1              5              1           TA             10
# 2911          0              3              1           TA              5
# 2912          0              4              2           TA              8
# 2913          0              1              1           TA              3
# 2914          1              3              1           TA              5
# 2915          0              3              1           TA              8
# 2916          0              1              1           Ex              3
# 2917          1              3              1           TA              5
# 2918          1              3              1           TA              5
# 2919          1              3              1           TA              5
# 2920          1              3              1           TA              6
# 2921          0              4              2           TA              8
# 2922          0              4              2           TA              8
# 2923          0              3              1           TA              5
# 2924          0              4              1           TA              7
# 2925          0              3              1           TA              6
# 2926          0              2              1           TA              5
# 2927          0              3              1           TA              6
# 2928          0              2              1           TA              6
# 2929          1              3              1           TA              9
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 0           Typ           2           Gd      Attchd         1960.0
# 1           Typ           0          NaN      Attchd         1961.0
# 2           Typ           0          NaN      Attchd         1958.0
# 3           Typ           2           TA      Attchd         1968.0
# 4           Typ           1           TA      Attchd         1997.0
# 5           Typ           1           Gd      Attchd         1998.0
# 6           Typ           0          NaN      Attchd         2001.0
# 7           Typ           0          NaN      Attchd         1992.0
# ...
# 20             RFn          2.0        546.0          TA          TA
# 21             RFn          2.0        528.0          TA          TA
# 22             RFn          2.0        663.0          TA          TA
# 23             Fin          2.0        480.0          TA          TA
# 24             Fin          2.0        500.0          TA          TA
# 25             Unf          1.0        304.0          TA          TA
# 26             Fin          2.0        525.0          TA          TA
# 27             NaN          0.0          0.0         NaN         NaN
# 28             Fin          2.0        511.0          TA          TA
# 29             Unf          1.0        264.0          TA          TA
# ...            ...          ...          ...         ...         ...
# 2900           Fin          3.0        714.0          TA          TA
# 2901           RFn          3.0        880.0          TA          TA
# 2902           Fin          3.0        682.0          TA          TA
# 2903           Unf          1.0        270.0          Fa          TA
# 2904           Fin          4.0        784.0          TA          TA
# 2905           Unf          2.0        402.0          TA          TA
# 2906           Fin          2.0        405.0          TA          TA
# 2907           NaN          0.0          0.0         NaN         NaN
# 2908           RFn          1.0        336.0          TA          TA
# 2909           RFn          1.0        336.0          TA          TA
# 2910           Fin          2.0        576.0          TA          TA
# 2911           RFn          1.0        288.0          TA          TA
# 2912           Unf          3.0        928.0          TA          TA
# 2913           NaN          0.0          0.0         NaN         NaN
# 2914           Unf          1.0        253.0          TA          Fa
# 2915           RFn          1.0        336.0          TA          TA
# 2916           NaN          0.0          0.0         NaN         NaN
# 2917           Unf          1.0        286.0          TA          TA
# 2918           NaN          0.0          0.0         NaN         NaN
# 2919           NaN          0.0          0.0         NaN         NaN
# 2920           Unf          1.0        286.0          TA          TA
# 2921           Unf          2.0        574.0          TA          TA
# 2922           Unf          2.0        560.0          TA          TA
# 2923           RFn          2.0        484.0          TA          TA
# 2924           Unf          2.0        576.0          TA          TA
# 2925           Unf          2.0        588.0          TA          TA
# 2926           Unf          2.0        484.0          TA          TA
# 2927           NaN          0.0          0.0         NaN         NaN
# 2928           RFn          2.0        418.0          TA          TA
# 2929           Fin          3.0        650.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 
# 25               0          0     NaN    NaN          NaN         0        7
# 26               0          0     NaN  MnPrv          NaN         0        4
# 27               0          0     NaN    NaN          NaN         0        4
# 28               0          0     NaN    NaN          NaN         0        6
# 29               0          0     NaN    NaN          NaN         0        2
# ...            ...        ...     ...    ...          ...       ...      ...
# 2900             0          0     NaN    NaN          NaN         0       11
# 2901             0          0     NaN    NaN          NaN         0        3
# 2902             0          0     NaN    NaN          NaN         0        9
# 2903             0          0     NaN    NaN          NaN         0        5
# 2904             0          0     NaN    NaN          NaN         0       11
# 2905             0          0     NaN    NaN          NaN         0        5
# 2906             0          0     NaN    NaN          NaN         0        3
# 2907             0          0     NaN    NaN          NaN         0        7
# 2908             0          0     NaN    NaN          NaN         0        5
# 2909             0          0     NaN    NaN          NaN         0        7
# 2910             0          0     NaN  GdPrv          NaN         0        6
# 2911             0          0     NaN    NaN          NaN         0       10
# 2912             0          0     NaN    NaN          NaN         0        3
# 2913             0          0     NaN    NaN          NaN         0        4
# 2914             0          0     NaN    NaN          NaN         0        5
# 2915             0          0     NaN    NaN          NaN         0        5
# 2916             0          0     NaN    NaN          NaN         0        8
# 2917             0          0     NaN    NaN          NaN         0       12
# 2918             0          0     NaN  GdPrv          NaN         0        6
# 2919             0          0     NaN    NaN          NaN         0        6
# 2920             0          0     NaN    NaN          NaN         0        4
# 2921             0          0     NaN    NaN          NaN         0        7
# 2922             0          0     NaN    NaN          NaN         0        7
# 2923             0          0     NaN    NaN          NaN         0        5
# 2924             0          0     NaN    NaN          NaN         0        9
# 2925             0          0     NaN  GdPrv          NaN         0        3
# 2926             0          0     NaN  MnPrv          NaN         0        6
# 2927             0          0     NaN  MnPrv         Shed       700        7
# 2928             0          0     NaN    NaN          NaN         0        4
# 2929             0          0     NaN    NaN          NaN         0       11
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 0        2010       WD          Normal     215000
# 1        2010       WD          Normal     105000
# 2        2010       WD          Normal     172000
# 3        2010       WD          Normal     244000
# 4        2010       WD          Normal     189900
# 5        2010       WD          Normal     195500
# 6        2010       WD          Normal     213500
# 7        2010       WD          Normal     191500
# 8        2010       WD          Normal     236500
# 9        2010       WD          Normal     189000
# 10       2010       WD          Normal     175900
# 11       2010       WD          Normal     185000
# 12       2010       WD          Normal     180400
# 13       2010       WD          Normal     171500
# 14       2010       WD          Normal     212000
# 15       2010       WD          Normal     538000
# 16       2010       WD          Normal     164000
# 17       2010       New        Partial     394432
# 18       2010       WD          Normal     141000
# 19       2010       WD          Normal     210000
# 20       2010       COD         Normal     190000
# 21       2010       WD          Family     170000
# 22       2010       WD          Normal     216000
# 23       2010       WD          Normal     149000
# 24       2010       WD          Normal     149900
# 25       2010       WD          Normal     142000
# 26       2010       WD          Normal     126000
# 27       2010     ConLI         Normal     115000
# 28       2010       WD          Normal     184000
# 29       2010       COD         Normal      96000
# ...       ...       ...            ...        ...
# 2900     2006       New        Partial     320000
# 2901     2006       New        Partial     369900
# 2902     2006       New        Partial     359900
# 2903     2006       WD          Normal      81500
# 2904     2006       WD          Normal     215000
# 2905     2006       WD          Normal     164000
# 2906     2006       WD          Normal     153500
# 2907     2006       WD         Abnorml      84500
# 2908     2006       WD          Normal     104500
# 2909     2006       WD          Normal     127000
# 2910     2006       WD          Normal     151400
# 2911     2006       WD          Normal     126500
# 2912     2006       WD          Normal     146500
# 2913     2006       WD          Normal      73000
# 2914     2006       WD          Normal      79400
# 2915     2006       WD          Normal     140000
# 2916     2006       WD         Abnorml      92000
# 2917     2006       WD         Abnorml      87550
# 2918     2006       WD          Normal      79500
# 2919     2006       WD          Normal      90500
# 2920     2006       WD         Abnorml      71000
# 2921     2006       WD          Normal     150900
# 2922     2006       WD          Family     188000
# 2923     2006       WD          Normal     160000
# 2924     2006       WD         Abnorml     131000
# 2925     2006       WD          Normal     142500
# 2926     2006       WD          Normal     131000
# 2927     2006       WD          Normal     132000
# 2928     2006       WD          Normal     170000
# 2929     2006       WD          Normal     188000
#
# [2930 rows x 82 columns]

# %% [markdown]
# This is our dataset. We need to now do a couple of things. We need to remove features we don't want to use in the model. These would be columns with a lot of missing values or columns that leak information about the sale (such as the year that the sale happened).

# %% [markdown]
# In creating our function: we want to:
#    - remove features that we don't want to use in the model, just based on the number of missing values or data leakage
#    - transform features into the proper format (numerical to categorical, scaling numerical, filling in missing values, etc)
#    - create new features by combining other features

# %%
#less than 5% NaN and over 5% NaN
# edit all changes then input into function. ex input transform to return cleaned df, etc

# Identify null values
null_series = df.isnull().sum()

# Isolate where columns have more than 5% null values
five_percent_nulls = null_series[null_series > (.05*len(df))]

#Drop these isolated columns from the dataframe
df = df.drop(five_percent_nulls.index, axis=1)

# %% [markdown]
# Now that the dataframe only contains columns with less than 5% null values, we can take another step in the cleaning process and:
#     - Drop text columns with one or more missing values
#     - Fill numerical column null values with the mode of the column.

# %%
# Isolate text datatype columns to see missing values
text_missing_counts = df.select_dtypes(include=['object']).isnull().sum().sort_values(ascending=False)

# Isolate the columns that have missing text
drop_text_col = text_missing_counts[text_missing_counts > 0]

# Drop the isolated columns from the dataframe
df = df.drop(drop_text_col.index, axis=1)

# %%
# Next we isolate the numerical columns
numeric = df.select_dtypes(include=['int','float']).isnull().sum()

# We then fill these values in with the mode. Note we isolate the columns with less than 5% null
numeric = numeric[(numeric < .05*len(df)) & (numeric > 0)].sort_values()

df = df.fillna(stats.mode)

# %%
# We can verify that there are no null values remaining
df.isnull().sum().value_counts()
# Out:
# 0    64
# dtype: int64

# %% [markdown]
# We can also add features that can help us in our analysis

# %%
years_sold = df['Yr Sold'] - df['Year Built']
years_sold[years_sold < 0]
# Out:
# 2180   -1
# dtype: int64

# %%
yrs_since_remod = df['Yr Sold'] - df['Year Remod/Add']
yrs_since_remod[yrs_since_remod < 0]
# Out:
# 1702   -1
# 2180   -2
# 2181   -1
# dtype: int64

# %%
# We can create new columns

df['Years_before_sale'] = df['Yr Sold'] - df['Year Built']
df['Years since remod'] = df['Yr Sold'] - df['Year Remod/Add']

# %%
# We can drop the rows with negative values for these columns
#df= df.drop([1702,2180,2181],axis=0)

# No longer need original year columns
df = df.drop(["Year Built", "Year Remod/Add"], axis = 1)

# %%
# Lastly, lets drop columns that aren't useful for our ML model and ones that may leak data

## Drop columns that aren't useful for ML
df = df.drop(["PID", "Order"], axis=1)

## Drop columns that leak info about the final sale
df = df.drop(["Mo Sold", "Sale Condition", "Sale Type", "Yr Sold"], axis=1)

# %% [markdown]
# We can now redo our transform_features function we created at the beginning to include all of these features we just put together.

# %%
def transform_features(df):
    null_series = df.isnull().sum()
    five_percent_nulls = null_series[null_series > (.05*len(df))]
    df = df.drop(five_percent_nulls.index, axis=1)
    
    text_missing_counts = df.select_dtypes(include=['object']).isnull().sum().sort_values(ascending=False)
    drop_text_col = text_missing_counts[text_missing_counts > 0]
    df = df.drop(drop_text_col.index, axis=1)
    
    numeric = df.select_dtypes(include=['int','float']).isnull().sum()
    numeric = numeric[(numeric < .05*len(df)) & (numeric > 0)].sort_values()
    df = df.fillna(stats.mode)
    
    years_sold = df['Yr Sold'] - df['Year Built']
    yrs_since_remod = df['Yr Sold'] - df['Year Remod/Add']
    df['Years_before_sale'] = df['Yr Sold'] - df['Year Built']
    df['Years since remod'] = df['Yr Sold'] - df['Year Remod/Add']
    df= df.drop([1702,2180,2181],axis=0)
    df = df.drop(["Year Built", "Year Remod/Add"], axis = 1)
    
    df = df.drop(["PID", "Order"], axis=1)
    df = df.drop(["Mo Sold", "Sale Condition", "Sale Type", "Yr Sold"], axis=1)
    
    return df

def select_features(df):
    return df[['Gr Liv Area', 'SalePrice']]

def train_and_test(df):
    train = df[:1460]
    test = df[1460:]
    
    numerical_train = train.select_dtypes(include=['integer','float'])
    numeric_test = test.select_dtypes(include=['integer','float'])
    
    
    features = numerical_train.columns.drop(['SalePrice'])
    
    lr = LinearRegression()
    lr.fit(train[features], train['SalePrice'])
    
    prediction = lr.predict(test[features])
    
    rmse = mean_squared_error(test['SalePrice'],prediction)**0.5
    return rmse

df= pd.read_csv("AmesHousing.tsv", delimiter= "\t")
transform_df = transform_features(df)
filtered_df = select_features(transform_df)
rmse = train_and_test(filtered_df)

rmse
# Out:
# 55275.36731241307

# %% [markdown]
# Comparing the rmse from the initial set of functions we can see we have already improved a little bit.

# %% [markdown]
# # Feature Selection

# %% [markdown]
# Now that we have cleaned and transformed a lot of the features in the data set, it's time to move on to feature selection for numerical features.
#
# What we want to do is select the numerical features, these are ones that we can directly coorelate with our target column, SalePrice. We keep only strongly correlated columns.
# We also want to select the nominal columns, or columns where there is no given order, and see how many unique values are among these. We then drop ones with high uniqueness to reduce variability.
#
# Lastly, we isolate these columns, convert them to categorical data type, and add them back into the data frame using dummy variables.

# %%
numerical_df = transform_df.select_dtypes(include=['int', 'float'])

# %%
# We take the numerical columns and correlate them with Sale Price
corr_map = numerical_df.corr()['SalePrice'].abs().sort_values()
corr_map
# Out:
# Misc Val             0.019273
# 3Ssn Porch           0.032268
# Low Qual Fin SF      0.037629
# Pool Area            0.068438
# MS SubClass          0.085128
# Overall Cond         0.101540
# Screen Porch         0.112280
# Kitchen AbvGr        0.119760
# Enclosed Porch       0.128685
# Bedroom AbvGr        0.143916
# Lot Area             0.267520
# 2nd Flr SF           0.269601
# Half Bath            0.284871
# Open Porch SF        0.316262
# Wood Deck SF         0.328183
# Fireplaces           0.474831
# TotRms AbvGrd        0.498574
# Years since remod    0.534985
# Full Bath            0.546118
# Years_before_sale    0.558979
# 1st Flr SF           0.635185
# Gr Liv Area          0.717596
# Overall Qual         0.801206
# SalePrice            1.000000
# Name: SalePrice, dtype: float64

# %%
# Lets only keep the features with a correlation values of 0.4 and higher

strong_corrs = corr_map[corr_map > 0.4]

transform_df = transform_df.drop(corr_map[corr_map < 0.4].index, axis=1)

# %%
strong_corrs
# Out:
# Fireplaces           0.474831
# TotRms AbvGrd        0.498574
# Years since remod    0.534985
# Full Bath            0.546118
# Years_before_sale    0.558979
# 1st Flr SF           0.635185
# Gr Liv Area          0.717596
# Overall Qual         0.801206
# SalePrice            1.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# The next thing we want to do is identify the columns we want converted to the categorical data type.
# All of the columns that can be categorized as nominal variables are candidates for being converted to categorical.

# %%
nominal_cols = ["PID", "MS SubClass", "MS Zoning", "Street", "Alley", "Land Contour", "Lot Config", "Neighborhood", 
                    "Condition 1", "Condition 2", "Bldg Type", "House Style", "Roof Style", "Roof Matl", "Exterior 1st", 
                    "Exterior 2nd", "Mas Vnr Type", "Foundation", "Heating", "Central Air", "Garage Type", 
                    "Misc Feature", "Sale Type", "Sale Condition"]

# We identify the nominal columns that we had in the transform dataframe
transform_cat_col = []
for col in nominal_cols:
    if col in transform_df:
        transform_cat_col.append(col)

# We also want to see how many unique values these columns have
unique_count = transform_df[transform_cat_col].apply(lambda col: len(col.value_counts())).sort_values()

# We can also experiment with dropping columns with uniqueness counts over 10 (an arbitrary number)
non_unique = unique_count[unique_count > 10].index
transform_df = transform_df.drop(non_unique,axis=1)

# %%
# Next we can select the remaining text columns and convert to categorical
text_cols = transform_df.select_dtypes(include=['object'])
for col in text_cols:
    transform_df[col] = transform_df[col].astype('category')

# Finally we want to create dummy columns and then add these back into the dataframe

dummies = pd.get_dummies(transform_df.select_dtypes(include=['category']))

transform_df = pd.concat([transform_df,dummies],axis=1).drop(text_cols,axis=1)

# %% [markdown]
# Now we update the select_features function.
# Just like we did with the transform features function, we take the above code and use it to update the select_features function

# %%
def transform_features(df):
    null_series = df.isnull().sum()
    five_percent_nulls = null_series[null_series > (.05*len(df))]
    df = df.drop(five_percent_nulls.index, axis=1)
    
    text_missing_counts = df.select_dtypes(include=['object']).isnull().sum().sort_values(ascending=False)
    drop_text_col = text_missing_counts[text_missing_counts > 0]
    df = df.drop(drop_text_col.index, axis=1)
    
    numeric = df.select_dtypes(include=['int','float']).isnull().sum()
    numeric = numeric[(numeric < .05*len(df)) & (numeric > 0)].sort_values()
    df = df.fillna(stats.mode)
    
    years_sold = df['Yr Sold'] - df['Year Built']
    yrs_since_remod = df['Yr Sold'] - df['Year Remod/Add']
    df['Years_before_sale'] = df['Yr Sold'] - df['Year Built']
    df['Years since remod'] = df['Yr Sold'] - df['Year Remod/Add']
    df= df.drop([1702,2180,2181],axis=0)
    df = df.drop(["Year Built", "Year Remod/Add"], axis = 1)
    
    df = df.drop(["PID", "Order"], axis=1)
    df = df.drop(["Mo Sold", "Sale Condition", "Sale Type", "Yr Sold"], axis=1)
    
    return df

def select_features(df,coeff_threshold=0.4, uniq_threshold=10):
    numerical_df = df.select_dtypes(include=['int', 'float'])
    corr_map = numerical_df.corr()['SalePrice'].abs().sort_values()
    df = df.drop(corr_map[corr_map < coeff_threshold].index,axis=1)
    
    nominal_cols = ["PID", "MS SubClass", "MS Zoning", "Street", "Alley", "Land Contour", "Lot Config", "Neighborhood", 
                    "Condition 1", "Condition 2", "Bldg Type", "House Style", "Roof Style", "Roof Matl", "Exterior 1st", 
                    "Exterior 2nd", "Mas Vnr Type", "Foundation", "Heating", "Central Air", "Garage Type", 
                    "Misc Feature", "Sale Type", "Sale Condition"]

    transform_cat_col = []
    for col in nominal_cols:
        if col in df:
            transform_cat_col.append(col)

    unique_count = df[transform_cat_col].apply(lambda col: len(col.value_counts())).sort_values()

    non_unique = unique_count[unique_count > 10].index
    df = df.drop(non_unique,axis=1)
    
    text_cols = df.select_dtypes(include=['object'])
    for col in text_cols:
        df[col] = df[col].astype('category')
    
    dummies = pd.get_dummies(df.select_dtypes(include=['category']))

    transform_df = pd.concat([df,dummies],axis=1).drop(text_cols,axis=1)
    
    
    return df

def train_and_test(df, k=0):
    train = df[:1460]
    test = df[1460:]
    
    numerical_df = df.select_dtypes(include=['integer','float'])
    features = numerical_df.columns.drop(['SalePrice'])
    lr = LinearRegression()
    
    if k == 0:
        lr.fit(train[features], train['SalePrice'])
        prediction = lr.predict(test[features])
        rmse = mean_squared_error(test['SalePrice'],prediction)**0.5
        return rmse
    if k == 1:
        shuffled_df = df.sample(frac=1)
        train = df[:1460]
        test = df[1460:]
        
        lr.fit(train[features], train['SalePrice'])
        prediction_one = lr.predict(test[features])
        rmse_one = mean_squared_error(test['SalePrice'],prediction_one)**0.5
        
        lr.fit(test[features], test['SalePrice'])
        prediction_two = lr.predict(train[features])
        rmse_two = mean_squared_error(train['SalePrice'], prediction_two)**0.5
        
        avg_rmse = np.mean([rmse_one, rmse_two])
        print(rmse_one)
        print(rmse_two)
        return avg_rmse
    
    
    else:
        kf = KFold(n_splits=k, shuffle=True)
        rmse_values = []
        for train_index, test_index in kf.split(df):
            train = df.iloc[train_index]
            test = df.iloc[test_index]
            
        lr.fit(train[features],train['SalePrice'])
        prediction = lr.predict(test[features])
        rmse = mean_squared_error(test['SalePrice'],prediction)**0.5
        rmse_values.append(rmse)
        
        avg_rmse = np.mean([rmse_values])
        
        return avg_rmse
        
        
        
df= pd.read_csv("AmesHousing.tsv", delimiter= "\t")
transform_df = transform_features(df)
filtered_df = select_features(transform_df)
rmse = train_and_test(filtered_df,k=4)

rmse
# Out:
# 32390.993333826256

# %% [markdown]
# We finally add in kFold cross validation in order as a resampling procedure for our model. This leaves us with a final rmse of about 32390.
#
# There is a lot that can be added to improve this rmse. These topics will be revisited in the next project and this project will be redone to try and reduce this even further.

# %%
# Out:
#       MS SubClass MS Zoning  Lot Area Street Lot Shape Land Contour Utilities  \
# 0              20        RL     31770   Pave       IR1          Lvl    AllPub
# 1              20        RH     11622   Pave       Reg          Lvl    AllPub
# 2              20        RL     14267   Pave       IR1          Lvl    AllPub
# 3              20        RL     11160   Pave       Reg          Lvl    AllPub
# 4              60        RL     13830   Pave       IR1          Lvl    AllPub
# 5              60        RL      9978   Pave       IR1          Lvl    AllPub
# 6             120        RL      4920   Pave       Reg          Lvl    AllPub
# 7             120        RL      5005   Pave       IR1          HLS    AllPub
# 8             120        RL      5389   Pave       IR1          Lvl    AllPub
# 9              60        RL      7500   Pave       Reg          Lvl    AllPub
# 10             60        RL     10000   Pave       IR1          Lvl    AllPub
# 11             20        RL      7980   Pave       IR1          Lvl    AllPub
# 12             60        RL      8402   Pave       IR1          Lvl    AllPub
# 13             20        RL     10176   Pave       Reg          Lvl    AllPub
# 14            120        RL      6820   Pave       IR1          Lvl    AllPub
# 15             60        RL     53504   Pave       IR2          HLS    AllPub
# 16             50        RL     12134   Pave       IR1          Bnk    AllPub
# 17             20        RL     11394   Pave       Reg          Lvl    AllPub
# 18             20        RL     19138   Pave       Reg          Lvl    AllPub
# 19             20        RL     13175   Pave       Reg          Lvl    AllPub
# 20             20        RL     11751   Pave       IR1          Lvl    AllPub
# 21             85        RL     10625   Pave       Reg          Lvl    AllPub
# 22             60        FV      7500   Pave       Reg          Lvl    AllPub
# 23             20        RL     11241   Pave       IR1          Lvl    AllPub
# 24             20        RL     12537   Pave       IR1          Lvl    AllPub
# 25             20        RL      8450   Pave       Reg          Lvl    AllPub
# 26             20        RL      8400   Pave       Reg          Lvl    AllPub
# 27             20        RL     10500   Pave       Reg          Lvl    AllPub
# 28            120        RH      5858   Pave       IR1          Lvl    AllPub
# 29            160        RM      1680   Pave       Reg          Lvl    AllPub
# ...           ...       ...       ...    ...       ...          ...       ...
# 2900           20        RL     13618   Pave       Reg          Lvl    AllPub
# 2901           20        RL     11443   Pave       Reg          Lvl    AllPub
# 2902           20        RL     11577   Pave       Reg          Lvl    AllPub
# 2903           20   A (agr)     31250   Pave       Reg          Lvl    AllPub
# 2904           90        RM      7020   Pave       Reg          Lvl    AllPub
# 2905          120        RM      4500   Pave       Reg          Lvl    AllPub
# 2906          120        RM      4500   Pave       Reg          Lvl    AllPub
# 2907           20        RL     17217   Pave       Reg          Lvl    AllPub
# 2908          160        RM      2665   Pave       Reg          Lvl    AllPub
# 2909          160        RM      2665   Pave       Reg          Lvl    AllPub
# 2910          160        RM      3964   Pave       Reg          Lvl    AllPub
# 2911           20        RL     10172   Pave       IR1          Lvl    AllPub
# 2912           90        RL     11836   Pave       IR1          Lvl    AllPub
# 2913          180        RM      1470   Pave       Reg          Lvl    AllPub
# 2914          160        RM      1484   Pave       Reg          Lvl    AllPub
# 2915           20        RL     13384   Pave       Reg          Lvl    AllPub
# 2916          180        RM      1533   Pave       Reg          Lvl    AllPub
# 2917          160        RM      1533   Pave       Reg          Lvl    AllPub
# 2918          160        RM      1526   Pave       Reg          Lvl    AllPub
# 2919          160        RM      1936   Pave       Reg          Lvl    AllPub
# 2920          160        RM      1894   Pave       Reg          Lvl    AllPub
# 2921           90        RL     12640   Pave       IR1          Lvl    AllPub
# 2922           90        RL      9297   Pave       Reg          Lvl    AllPub
# 2923           20        RL     17400   Pave       Reg          Low    AllPub
# 2924           20        RL     20000   Pave       Reg          Lvl    AllPub
# 2925           80        RL      7937   Pave       IR1          Lvl    AllPub
# 2926           20        RL      8885   Pave       IR1          Low    AllPub
# 2927           85        RL     10441   Pave       Reg          Lvl    AllPub
# 2928           20        RL     10010   Pave       Reg          Lvl    AllPub
# 2929           60        RL      9627   Pave       Reg          Lvl    AllPub
#
#      Lot Config Land Slope Neighborhood Condition 1 Condition 2 Bldg Type  \
# 0        Corner        Gtl        NAmes        Norm        Norm      1Fam
# 1        Inside        Gtl        NAmes       Feedr        Norm      1Fam
# 2        Corner        Gtl        NAmes        Norm        Norm      1Fam
# 3        Corner        Gtl        NAmes        Norm        Norm      1Fam
# 4        Inside        Gtl      Gilbert        Norm        Norm      1Fam
# 5        Inside        Gtl      Gilbert        Norm        Norm      1Fam
# 6        Inside        Gtl      StoneBr        Norm        Norm    TwnhsE
# 7        Inside        Gtl      StoneBr        Norm        Norm    TwnhsE
# 8        Inside        Gtl      StoneBr        Norm        Norm    TwnhsE
# 9        Inside        Gtl      Gilbert        Norm        Norm      1Fam
# 10       Corner        Gtl      Gilbert        Norm        Norm      1Fam
# 11       Inside        Gtl      Gilbert        Norm        Norm      1Fam
# 12       Inside        Gtl      Gilbert        Norm        Norm      1Fam
# 13       Inside        Gtl      Gilbert        Norm        Norm      1Fam
# 14       Corner        Gtl      StoneBr        Norm        Norm    TwnhsE
# 15      CulDSac        Mod      StoneBr        Norm        Norm      1Fam
# 16       Inside        Mod      Gilbert        Norm        Norm      1Fam
# 17       Corner        Gtl      StoneBr        Norm        Norm      1Fam
# 18       Corner        Gtl      Gilbert        Norm        Norm      1Fam
# 19       Inside        Gtl       NWAmes        Norm        Norm      1Fam
# 20       Inside        Gtl       NWAmes        Norm        Norm      1Fam
# 21       Inside        Gtl       NWAmes        Norm        Norm      1Fam
# 22       Inside        Gtl      Somerst        Norm        Norm      1Fam
# 23      CulDSac        Gtl        NAmes        Norm        Norm      1Fam
# 24      CulDSac        Gtl        NAmes        Norm        Norm      1Fam
# 25       Inside        Gtl        NAmes        Norm        Norm      1Fam
# 26       Corner        Gtl        NAmes        Norm        Norm      1Fam
# 27          FR2        Gtl        NAmes        Norm        Norm      1Fam
# 28          FR2        Gtl        NAmes        Norm        Norm    TwnhsE
# 29       Inside        Gtl       BrDale        Norm        Norm     Twnhs
# ...         ...        ...          ...         ...         ...       ...
# 2900     Corner        Gtl       Timber        Norm        Norm      1Fam
# 2901     Inside        Gtl       Timber        Norm        Norm      1Fam
# 2902     Inside        Gtl       Timber        Norm        Norm      1Fam
# 2903     Inside        Gtl      Mitchel      Artery        Norm      1Fam
# 2904     Inside        Gtl      Mitchel        Norm        Norm    Duplex
# 2905        FR2        Gtl      Mitchel        Norm        Norm     Twnhs
# 2906        FR2        Gtl      Mitchel        Norm        Norm    TwnhsE
# 2907     Inside        Gtl      Mitchel        Norm        Norm      1Fam
# 2908     Inside        Gtl      MeadowV        Norm        Norm    TwnhsE
# 2909     Inside        Gtl      MeadowV        Norm        Norm    TwnhsE
# 2910     Inside        Gtl      MeadowV        Norm        Norm    TwnhsE
# 2911     Inside        Gtl      Mitchel        Norm        Norm      1Fam
# 2912     Corner        Gtl      Mitchel        Norm        Norm    Duplex
# 2913     Inside        Gtl      MeadowV        Norm        Norm     Twnhs
# 2914     Inside        Gtl      MeadowV        Norm        Norm    TwnhsE
# 2915     Inside        Mod      Mitchel        Norm        Norm      1Fam
# 2916     Inside        Gtl      MeadowV        Norm        Norm     Twnhs
# 2917     Inside        Gtl      MeadowV        Norm        Norm     Twnhs
# 2918     Inside        Gtl      MeadowV        Norm        Norm     Twnhs
# 2919     Inside        Gtl      MeadowV        Norm        Norm     Twnhs
# 2920     Inside        Gtl      MeadowV        Norm        Norm    TwnhsE
# 2921     Inside        Gtl      Mitchel        Norm        Norm    Duplex
# 2922     Inside        Gtl      Mitchel        Norm        Norm    Duplex
# 2923     Inside        Mod      Mitchel        Norm        Norm      1Fam
# 2924     Inside        Gtl      Mitchel        Norm        Norm      1Fam
# 2925    CulDSac        Gtl      Mitchel        Norm        Norm      1Fam
# 2926     Inside        Mod      Mitchel        Norm        Norm      1Fam
# 2927     Inside        Gtl      Mitchel        Norm        Norm      1Fam
# 2928     Inside        Mod      Mitchel        Norm        Norm      1Fam
# 2929     Inside        Mod      Mitchel        Norm        Norm      1Fam
#
#      House Style  Overall Qual  Overall Cond Roof Style Roof Matl  \
# 0         1Story             6             5        Hip   CompShg
# 1         1Story             5             6      Gable   CompShg
# 2         1Story             6             6        Hip   CompShg
# 3         1Story             7             5        Hip   CompShg
# 4         2Story             5             5      Gable   CompShg
# 5         2Story             6             6      Gable   CompShg
# 6         1Story             8             5      Gable   CompShg
# 7         1Story             8             5      Gable   CompShg
# 8         1Story             8             5      Gable   CompShg
# 9         2Story             7             5      Gable   CompShg
# 10        2Story             6             5      Gable   CompShg
# 11        1Story             6             7      Gable   CompShg
# 12        2Story             6             5      Gable   CompShg
# 13        1Story             7             5      Gable   CompShg
# 14        1Story             8             5      Gable   CompShg
# 15        2Story             8             5        Hip   CompShg
# 16        1.5Fin             8             7      Gable   CompShg
# 17        1Story             9             2        Hip   CompShg
# 18        1Story             4             5      Gable   CompShg
# 19        1Story             6             6      Gable   CompShg
# 20        1Story             6             6        Hip   CompShg
# 21        SFoyer             7             6      Gable   CompShg
# 22        2Story             7             5      Gable   CompShg
# 23        1Story             6             7      Gable   CompShg
# 24        1Story             5             6      Gable   CompShg
# 25        1Story             5             6      Gable   CompShg
# 26        1Story             4             5      Gable   CompShg
# 27        1Story             4             5      Gable   CompShg
# 28        1Story             7             5      Gable   CompShg
# 29        2Story             6             5      Gable   CompShg
# ...          ...           ...           ...        ...       ...
# 2900      1Story             8             5      Gable   CompShg
# 2901      1Story             8             5        Hip   CompShg
# 2902      1Story             9             5        Hip   CompShg
# 2903      1Story             1             3      Gable   CompShg
# 2904      SFoyer             7             5      Gable   CompShg
# 2905      1Story             6             5        Hip   CompShg
# 2906      1Story             6             5        Hip   CompShg
# 2907      1Story             5             5      Gable   CompShg
# 2908      2Story             5             6      Gable   CompShg
# 2909      2Story             5             6      Gable   CompShg
# 2910      2Story             6             4      Gable   CompShg
# 2911      1Story             5             7      Gable   CompShg
# 2912      1Story             5             5      Gable   CompShg
# 2913      SFoyer             4             6      Gable   CompShg
# 2914      2Story             4             4      Gable   CompShg
# 2915      1Story             5             5      Gable   CompShg
# 2916      SFoyer             5             7      Gable   CompShg
# 2917      2Story             4             5      Gable   CompShg
# 2918      2Story             4             5      Gable   CompShg
# 2919      2Story             4             7      Gable   CompShg
# 2920      2Story             4             5      Gable   CompShg
# 2921      1Story             6             5      Gable   CompShg
# 2922      1Story             5             5      Gable   CompShg
# 2923      1Story             5             5      Gable   CompShg
# 2924      1Story             5             7      Gable   CompShg
# 2925        SLvl             6             6      Gable   CompShg
# 2926      1Story             5             5      Gable   CompShg
# 2927      SFoyer             5             5      Gable   CompShg
# 2928      1Story             5             5      Gable   CompShg
# 2929      2Story             7             5      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 0         BrkFace      Plywood          112         TA         TA     CBlock
# 1         VinylSd      VinylSd            0         TA         TA     CBlock
# 2         Wd Sdng      Wd Sdng          108         TA         TA     CBlock
# 3         BrkFace      BrkFace            0         Gd         TA     CBlock
# 4         VinylSd      VinylSd            0         TA         TA      PConc
# 5         VinylSd      VinylSd           20         TA         TA      PConc
# 6         CemntBd      CmentBd            0         Gd         TA      PConc
# 7         HdBoard      HdBoard            0         Gd         TA      PConc
# 8         CemntBd      CmentBd            0         Gd         TA      PConc
# 9         VinylSd      VinylSd            0         TA         TA      PConc
# 10        HdBoard      HdBoard            0         TA         TA      PConc
# 11        HdBoard      HdBoard            0         TA         Gd      PConc
# 12        VinylSd      VinylSd            0         TA         TA      PConc
# 13        HdBoard      HdBoard            0         TA         TA      PConc
# 14        HdBoard      HdBoard            0         Gd         TA      PConc
# 15        CemntBd      Wd Shng          603         Ex         TA      PConc
# 16        Wd Sdng      Wd Sdng            0         Gd         TA       Wood
# 17        VinylSd      VinylSd          350         Gd         TA      PConc
# 18        VinylSd      VinylSd            0         TA         TA     CBlock
# 19        Plywood      Plywood          119         TA         TA     CBlock
# 20        Plywood      Plywood          480         TA         TA     CBlock
# 21        Plywood      Plywood           81         TA         TA     CBlock
# 22        VinylSd      VinylSd            0         Gd         TA      PConc
# 23        Wd Sdng      Wd Sdng          180         TA         TA     CBlock
# 24        VinylSd      VinylSd            0         TA         TA     CBlock
# 25        VinylSd      VinylSd            0         TA         TA     CBlock
# 26        Plywood      Plywood            0         TA         TA     CBlock
# 27        HdBoard      HdBoard            0         TA         TA     CBlock
# 28        MetalSd      MetalSd            0         Gd         TA      PConc
# 29        HdBoard      HdBoard          504         TA         TA     CBlock
# ...           ...          ...          ...        ...        ...        ...
# 2900      VinylSd      VinylSd          198         Gd         TA      PConc
# 2901      VinylSd      VinylSd          208         Gd         TA      PConc
# 2902      VinylSd      VinylSd          382         Ex         TA      PConc
# 2903       CBlock      VinylSd            0         TA         Fa     CBlock
# 2904      MetalSd      MetalSd          200         TA         Gd      PConc
# 2905      VinylSd      VinylSd          116         TA         TA      PConc
# 2906      VinylSd      VinylSd          443         TA         Gd      PConc
# 2907      VinylSd      VinylSd            0         TA         TA      PConc
# 2908      CemntBd      CmentBd            0         TA         TA      PConc
# 2909      CemntBd      CmentBd            0         TA         TA      PConc
# 2910      CemntBd      CmentBd            0         TA         TA     CBlock
# 2911      Plywood      Plywood            0         TA         TA     CBlock
# 2912      Plywood      Plywood            0         TA         TA     CBlock
# 2913      CemntBd      CmentBd            0         TA         TA     CBlock
# 2914      CemntBd      CmentBd            0         TA         TA     CBlock
# 2915      Plywood      Plywood          194         TA         TA      PConc
# 2916      CemntBd      CmentBd            0         TA         TA     CBlock
# 2917      CemntBd      CmentBd            0         TA         TA     CBlock
# 2918      CemntBd      CmentBd            0         TA         TA     CBlock
# 2919      CemntBd      CmentBd            0         TA         TA     CBlock
# 2920      CemntBd      CmentBd            0         TA         TA     CBlock
# 2921      Plywood      Plywood            0         TA         TA     CBlock
# 2922      Plywood      Plywood            0         TA         TA     CBlock
# 2923      BrkFace      BrkFace            0         TA         TA     CBlock
# 2924      VinylSd      VinylSd            0         TA         TA     CBlock
# 2925      HdBoard      HdBoard            0         TA         TA     CBlock
# 2926      HdBoard      HdBoard            0         TA         TA     CBlock
# 2927      HdBoard      Wd Shng            0         TA         TA      PConc
# 2928      HdBoard      HdBoard            0         TA         TA     CBlock
# 2929      HdBoard      HdBoard           94         TA         TA      PConc
#
#      BsmtFin SF 1 BsmtFin SF 2 Bsmt Unf SF Total Bsmt SF Heating Heating QC  \
# 0             639            0         441          1080    GasA         Fa
# 1             468          144         270           882    GasA         TA
# 2             923            0         406          1329    GasA         TA
# 3            1065            0        1045          2110    GasA         Ex
# 4             791            0         137           928    GasA         Gd
# 5             602            0         324           926    GasA         Ex
# 6             616            0         722          1338    GasA         Ex
# 7             263            0        1017          1280    GasA         Ex
# 8            1180            0         415          1595    GasA         Ex
# 9               0            0         994           994    GasA         Gd
# 10              0            0         763           763    GasA         Gd
# 11            935            0         233          1168    GasA         Ex
# 12              0            0         789           789    GasA         Gd
# 13            637            0         663          1300    GasA         Gd
# 14            368         1120           0          1488    GasA         TA
# 15           1416            0         234          1650    GasA         Ex
# 16            427            0         132           559    GasA         Gd
# 17           1445            0         411          1856    GasA         Ex
# 18            120            0         744           864    GasA         Ex
# 19            790          163         589          1542    GasA         TA
# 20            705            0        1139          1844    GasA         Ex
# 21            885          168           0          1053    GasA         TA
# 22            533            0         281           814    GasA         Ex
# 23            578            0         426          1004    GasA         Ex
# 24            734            0         344          1078    GasA         Ex
# 25            775            0         281          1056    GasA         Ex
# 26            804           78           0           882    GasA         TA
# 27            432            0         432           864    GasA         TA
# 28           1051            0         354          1405    GasA         Ex
# 29            156            0         327           483    GasA         TA
# ...           ...          ...         ...           ...     ...        ...
# 2900         1350            0         378          1728    GasA         Ex
# 2901         1460            0         408          1868    GasA         Ex
# 2902         1455            0         383          1838    GasA         Ex
# 2903            0            0           0             0    GasA         TA
# 2904         1243            0          45          1288    GasA         Gd
# 2905          897            0         319          1216    GasA         Ex
# 2906         1201            0          36          1237    GasA         Ex
# 2907            0            0        1140          1140    GasA         Ex
# 2908            0            0         264           264    GasA         TA
# 2909          548          173          36           757    GasA         Ex
# 2910          837            0         105           942    GasA         Gd
# 2911          441            0         423           864    GasA         Ex
# 2912          149            0        1503          1652    GasA         TA
# 2913          522            0         108           630    GasA         TA
# 2914          252            0         294           546    GasA         TA
# 2915          119          344         641          1104    GasA         Fa
# 2916          553            0          77           630    GasA         Ex
# 2917          408            0         138           546    GasA         TA
# 2918            0            0         546           546    GasA         TA
# 2919            0            0         546           546    GasA         Gd
# 2920          252            0         294           546    GasA         TA
# 2921          936          396         396          1728    GasA         TA
# 2922         1606            0         122          1728    GasA         TA
# 2923          936            0         190          1126    GasA         Fa
# 2924         1224            0           0          1224    GasA         Ex
# 2925          819            0         184          1003    GasA         TA
# 2926          301          324         239           864    GasA         TA
# 2927          337            0         575           912    GasA         TA
# 2928         1071          123         195          1389    GasA         Gd
# 2929          758            0         238           996    GasA         Ex
#
#      Central Air  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0              Y        1656           0                0         1656
# 1              Y         896           0                0          896
# 2              Y        1329           0                0         1329
# 3              Y        2110           0                0         2110
# 4              Y         928         701                0         1629
# 5              Y         926         678                0         1604
# 6              Y        1338           0                0         1338
# 7              Y        1280           0                0         1280
# 8              Y        1616           0                0         1616
# 9              Y        1028         776                0         1804
# 10             Y         763         892                0         1655
# 11             Y        1187           0                0         1187
# 12             Y         789         676                0         1465
# 13             Y        1341           0                0         1341
# 14             Y        1502           0                0         1502
# 15             Y        1690        1589                0         3279
# 16             Y        1080         672                0         1752
# 17             Y        1856           0                0         1856
# 18             Y         864           0                0          864
# 19             Y        2073           0                0         2073
# 20             Y        1844           0                0         1844
# 21             Y        1173           0                0         1173
# 22             Y         814         860                0         1674
# 23             Y        1004           0                0         1004
# 24             Y        1078           0                0         1078
# 25             Y        1056           0                0         1056
# 26             Y         882           0                0          882
# 27             Y         864           0                0          864
# 28             Y        1337           0                0         1337
# 29             Y         483         504                0          987
# ...          ...         ...         ...              ...          ...
# 2900           Y        1960           0                0         1960
# 2901           Y        2028           0                0         2028
# 2902           Y        1838           0                0         1838
# 2903           Y        1600           0                0         1600
# 2904           Y        1368           0                0         1368
# 2905           Y        1216           0                0         1216
# 2906           Y        1337           0                0         1337
# 2907           Y        1140           0                0         1140
# 2908           Y         616         688                0         1304
# 2909           Y         925         550                0         1475
# 2910           Y        1291        1230                0         2521
# 2911           Y         874           0                0          874
# 2912           Y        1652           0                0         1652
# 2913           Y         630           0                0          630
# 2914           Y         546         546                0         1092
# 2915           Y        1360           0                0         1360
# 2916           Y         630           0                0          630
# 2917           Y         546         546                0         1092
# 2918           Y         546         546                0         1092
# 2919           Y         546         546                0         1092
# 2920           Y         546         546                0         1092
# 2921           Y        1728           0                0         1728
# 2922           Y        1728           0                0         1728
# 2923           Y        1126           0                0         1126
# 2924           Y        1224           0                0         1224
# 2925           Y        1003           0                0         1003
# 2926           Y         902           0                0          902
# 2927           Y         970           0                0          970
# 2928           Y        1389           0                0         1389
# 2929           Y         996        1004                0         2000
#
#      Bsmt Full Bath Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0                 1              0          1          0              3
# 1                 0              0          1          0              2
# 2                 0              0          1          1              3
# 3                 1              0          2          1              3
# 4                 0              0          2          1              3
# 5                 0              0          2          1              3
# 6                 1              0          2          0              2
# 7                 0              0          2          0              2
# 8                 1              0          2          0              2
# 9                 0              0          2          1              3
# 10                0              0          2          1              3
# 11                1              0          2          0              3
# 12                0              0          2          1              3
# 13                1              0          1          1              2
# 14                1              0          1          1              1
# 15                1              0          3          1              4
# 16                0              0          2          0              4
# 17                1              0          1          1              1
# 18                0              0          1          0              2
# 19                1              0          2          0              3
# 20                0              0          2          0              3
# 21                1              0          2          0              3
# 22                1              0          2          1              3
# 23                1              0          1          0              2
# 24                1              0          1          1              3
# 25                1              0          1          0              3
# 26                1              0          1          0              2
# 27                0              0          1          0              3
# 28                1              0          2          0              2
# 29                0              0          1          1              2
# ...             ...            ...        ...        ...            ...
# 2900              1              0          2          0              3
# 2901              1              0          2          0              2
# 2902              1              0          2          0              3
# 2903              0              0          1          1              3
# 2904              2              0          2          0              2
# 2905              1              0          2          0              2
# 2906              1              0          2          0              2
# 2907              0              0          1          0              3
# 2908              0              0          1          1              3
# 2909              0              0          2          0              4
# 2910              1              0          2          1              5
# 2911              1              0          1          0              3
# 2912              0              0          2          0              4
# 2913              1              0          1          0              1
# 2914              0              0          1          1              3
# 2915              1              0          1          0              3
# 2916              1              0          1          0              1
# 2917              0              0          1          1              3
# 2918              0              0          1          1              3
# 2919              0              0          1          1              3
# 2920              0              0          1          1              3
# 2921              0              0          2          0              4
# 2922              2              0          2          0              4
# 2923              1              0          2          0              3
# 2924              1              0          1          0              4
# 2925              1              0          1          0              3
# 2926              1              0          1          0              2
# 2927              0              1          1          0              3
# 2928              1              0          1          0              2
# 2929              0              0          2          1              3
#
#       Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0                 1           TA              7        Typ           2
# 1                 1           TA              5        Typ           0
# 2                 1           Gd              6        Typ           0
# 3                 1           Ex              8        Typ           2
# 4                 1           TA              6        Typ           1
# 5                 1           Gd              7        Typ           1
# 6                 1           Gd              6        Typ           0
# 7                 1           Gd              5        Typ           0
# 8                 1           Gd              5        Typ           1
# 9                 1           Gd              7        Typ           1
# 10                1           TA              7        Typ           1
# 11                1           TA              6        Typ           0
# 12                1           TA              7        Typ           1
# 13                1           Gd              5        Typ           1
# 14                1           Gd              4        Typ           0
# 15                1           Ex             12        Mod           1
# 16                1           TA              8        Typ           0
# 17                1           Ex              8        Typ           1
# 18                1           TA              4        Typ           0
# 19                1           TA              7       Min1           2
# 20                1           TA              7        Typ           1
# 21                1           Gd              6        Typ           2
# 22                1           Gd              7        Typ           0
# 23                1           TA              5        Typ           1
# 24                1           TA              6        Typ           1
# 25                1           TA              6        Typ           1
# 26                1           TA              4        Typ           0
# 27                1           TA              5        Typ           1
# 28                1           Gd              5        Typ           1
# 29                1           TA              5        Typ           0
# ...             ...          ...            ...        ...         ...
# 2900              1           Gd              8        Typ           2
# 2901              1           Gd              7        Typ           2
# 2902              1           Ex              9        Typ           1
# 2903              1           TA              6        Mod           0
# 2904              2           TA              8        Typ           0
# 2905              1           TA              5        Typ           0
# 2906              1           TA              5        Typ           0
# 2907              1           TA              6        Typ           0
# 2908              1           TA              5        Typ           1
# 2909              1           TA              6        Typ           1
# 2910              1           TA             10       Maj1           1
# 2911              1           TA              5        Typ           0
